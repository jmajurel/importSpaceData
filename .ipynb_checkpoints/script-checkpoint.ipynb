# %% [markdown]
# # Import space data project
#
# This project was initiate to read, process and feed spacegraphqlapi mongodb database
#
# ## Data
# The data are from NASA website https://exoplanetarchive.ipac.caltech.edu/cgi-bin/TblView/nph-tblView?app=ExoTbls&config=PS

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
exo_planets = pd.read_csv("data/PS_2022.06.24_08.14.32.csv", index_col=0, skiprows=292)

# %% [markdown]
# ## Data exploration

# %%
exo_planets.head(10)
# Out:
#          hostname pl_letter  hd_name       hip_name           tic_id  \
# ame
# 11 Com b   11 Com         b  HD 1073  3    HIP 6020       TIC 724370
# 11 Com b   11 Com         b  HD 1073  3    HIP 6020       TIC 724370
# 11 UMi b   11 UMi         b  HD 1367  6    HIP 7479       TIC 230061
# 11 UMi b   11 UMi         b  HD 1367  6    HIP 7479       TIC 230061
# 11 UMi b   11 UMi         b  HD 1367  6    HIP 7479       TIC 230061
# 14 And b   14 And         b  HD 2213  5    HIP 1160  6    TIC 333225
# 14 And b   14 And         b  HD 2213  5    HIP 1160  6    TIC 333225
# 14 Her b   14 Her         b  HD 1456  5    HIP 7924       TIC 219483
# 14 Her b   14 Her         b  HD 1456  5    HIP 7924       TIC 219483
# 14 Her b   14 Her         b  HD 1456  5    HIP 7924       TIC 219483
#
#                                 gaia_id default_flag  sy_snum  sy_pnum  \
# ame
# 11 Com b  7    Gaia DR2 394694541310633       696  1      2.0      1.0
# ...

# %%
exo_planets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1667 entries, 11 Com b to HD 155193 b
# Columns: 285 entries, hostname to pl_ntranspec
# dtypes: float64(249), object(36)
# memory usage: 3.6+ MB

# %%
exo_planets.shape
# Out:
# (1667, 285)

# %%
exo_planets.columns
# Out:
# Index(['hostname', 'pl_letter', 'hd_name', 'hip_name', 'tic_id', 'gaia_id',
#        'default_flag', 'sy_snum', 'sy_pnum', 'sy_mnum',
#        ...
#        'sy_kepmagerr2', 'rowupdate', 'pl_pubdate', 'releasedate', 'pl_nnotes',
#        'st_nphot', 'st_nrvc', 'st_nspec', 'pl_nespec', 'pl_ntranspec'],
#       dtype='object', length=285)
